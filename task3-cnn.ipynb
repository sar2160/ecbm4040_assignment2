# %% [markdown]
# # ECBM E4040 - Assignment 2 - Task 3: Convolutional Neural Network (CNN)
#
# In this task, you are going to first practice the forward/backward propagation of the convolutional operations with Numpy. After that, we will introduce TensorFlow with which you'll create your CNN model for an image classification task.

# %% [markdown]
# ## CNNs:
# This is one of the good posts describing CNNs:
#
# [https://adeshpande3.github.io/adeshpande3.github.io/A-Beginner%27s-Guide-To-Understanding-Convolutional-Neural-Networks/](https://adeshpande3.github.io/adeshpande3.github.io/A-Beginner%27s-Guide-To-Understanding-Convolutional-Neural-Networks/)
#
# Convolutional neural networks (CNNs) are a type of neural networks which is highly effective for image processing.
#
# Remember when we build an MLP model, each input is multiplied by its own weights. When the input dimension or the first layer is too large, we will need a giant matrix to store our weights. This could easily become a problem in image processing since the dimension of a vectorized image could easily exceed 1000 (consider CIFAR-10 which has images of shape 32×32=1024, yet the resolution is so low).
#
# In CNN, the weights can be shared: the same filter (also known as 'weights' or 'kernel') moves over the input, and at each position an output value is calculated. This means the same weights are used by the entire input, therefore saving a lot of memory.
#
# ![Illustration of the CNN](./ecbm4040/notebook_images/task3_1.jpg)
# Image source: [here](https://developer.apple.com/library/content/documentation/Performance/Conceptual/vImage/ConvolutionOperations/ConvolutionOperations.html)
#
# __Convolution:__  In the picture above, the input is a 7-by-7 image, and the filter is shown as a blue 3-by-3 grid. The filter overlaps with the top-left corner of the input, and we perform an element-wise multiplication followed by a summation, then put the sum into the output matrix. The filter then moves several pixels right, covering a new input area so a new sum can be derived.
#
# __Training:__ One thing to remember is that there would be a lot of filters for each layer in a CNN, and the goal of training is to find the best filters for your task. Each filter tries to capture one specific feature. Typically, in the first convolutional layer which directly looks at your input, the filters try to capture information about color and edges which we know as local features; in higher layers, due to the effect of max-pooling, the receptive-fields of filters becomes large so more global and complex features can be detected.
#
# __Architecture:__ For classification tasks, a CNN usually starts with convolution followed by max-pooling. After that, the feature maps will be flattened so that we could append fully connected layers. Common activation functions include ReLu, ELU in the convolution layers, and softmax in the fully connected layers (to calculate the classification scores).
#
# ---
#
# ### Terminology
#
# * __Convolution__: element-wise multiplication followed by summation of your input and one of your filters in the CNN context.
# * __Filter/kernel/weights__: a grid or a set of grids typically smaller than your input size that moves over the input space to generate output. Each filter captures one type of feature.
# * __Feature/feature maps__: the output of a hidden layer. Think of it as another representation of your data.
# * __Pooling__: an downsampling operation that joins local information together, so the higher layers' receptive fields can be bigger. The most seen pooling operation is max-pooling, which outputs the maximum of all values inside the pool.
# * __Flatten__: a junction between convolution layers and fully connected layers. Used to turn 2-D feature maps into 1-D. For tasks such as image segmentation where the output also needs to be 2-D, this won't be used.
# * __Border mode__: usually refers to 'VALID' or 'SAME'. Under 'VALID' mode, only when the filter and the input fully overlap can a convolution be conducted; under 'SAME' mode, the output size is the same as the input size, and when the filter and the input don't fully overlap (happens at the edge/corner of input) we pad zeroes (or other designated numbers) and then do convolution.

# %%
# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# Import modules
from __future__ import print_function
import tensorflow as tf
import numpy as np
from ecbm4040.cifar_utils import load_data
from matplotlib import pyplot as plt

# %% [markdown]
# ## Part 1: Getting a sense of convolution

# %% [markdown]
# ### conv2d feedforward
#
# Implement a Numpy naive 2-D convolution feedforward function. We ask you to simply do the element-wise multiplication and summation. Also, don't need to worry about the efficiency of your function. Use loops as many as you like.
#
# <span style="color:red">__TODO:__</span> Finish the function __conv2d_forward__ in __ecbm4040/layer_funcs.py__. After that, run the following cell blocks, which will give the output of your convolution function. Detailed instructions have been given in the comments of __layer_func.py__. __We need to judge your output to give you credits__.

# %%
from ecbm4040.layer_funcs import conv2d_forward

# Set test parameters.
x_shape = (2, 4, 4, 3)
w_shape = (3, 4, 4, 3)
x = np.linspace(-0.1, 0.5, num=np.prod(x_shape)).reshape(x_shape)
w = np.linspace(-0.2, 0.3, num=np.prod(w_shape)).reshape(w_shape)
b = np.linspace(-0.1, 0.2, num=3)
pad = 1
stride = 2
your_feedforward = conv2d_forward(x, w, b, pad, stride)
print(your_feedforward)
your_feedforward.shape
# Out:
# [[[[-0.24138903  0.21338093  0.6681509 ]
#    [-0.29391829  0.24671108  0.78734045]]
#
#   [[-0.51590063  0.28230696  1.08051454]
#    [-0.61135959  0.2727074   1.15677438]]]
#
#
#  [[[-0.99122782  0.8372926   2.66581303]
#    [-1.12961649  0.78476334  2.69914317]]
#
#   [[-1.60917703  0.56278101  2.73473905]
#    [-1.7904954   0.46732205  2.72513949]]]]
# (2, 2, 2, 3)

# %%
## Testing CNN implementation with tf (ignoring bias)
import tensorflow as tf

#https://www.tensorflow.org/api_docs/python/tf/nn/conv2d

w_tf = np.swapaxes(w,0,1) # TF wants input in shape [height, width, in channels , out channels]
w_tf = np.swapaxes(w_tf,1,2)
w_tf = np.swapaxes(w_tf,2,3)

print(w_tf.shape)

init_op = tf.initialize_all_variables()

with tf.Session() as sess:
    sess.run(init_op)
    strides = [1, stride, stride, 1]
    out = tf.nn.conv2d(x_padded.astype('float32'), w_tf.astype('float32'), strides, "VALID")
    result = sess.run(out)
    print(result)
# Out:
# (4, 4, 3, 3)
# WARNING:tensorflow:From /home/ecbm4040/.local/lib/python3.5/site-packages/tensorflow/python/util/tf_should_use.py:175: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-f41770d86a1a> in <module>()
#      15     sess.run(init_op)
#      16     strides = [1, stride, stride, 1]
# ---> 17     out = tf.nn.conv2d(x_padded.astype('float32'), w_tf.astype('float32'), strides, "VALID")
#      18     result = sess.run(out)
#      19     print(result)
#
# NameError: name 'x_padded' is not defined

# %% [markdown]
# ### conv2d backpropogation (optional, bonus +10 points)
#
# <p style="color:red">This function is optional, but a bonus 10 points will be given if you solve it correctly.</p>
#
# Implement a Numpy naive 2-D convolution backpropagation function. Again, don't worry about the efficienty.
#
# <span style="color:red">__TODO:__</span> Finish the function __conv2d_backward__ in __ecbm4040/layer_funcs.py__. After that, run the following cell blocks, which will give the output of your backpropagation. Detailed instructions have been given in the comments of __layer_func.py__. __We need to judge your output to give you credits__.

# %%
from ecbm4040.layer_funcs import conv2d_backward
# Set test parameters. Please don't change it.
np.random.seed(123)
d_top = np.random.normal(size=your_feedforward.shape)
your_dw, your_db = conv2d_backward(d_top, x, w, b, pad, stride)
print(your_dw)
print('*'*50)
print(your_db)
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# <ipython-input-5-6a76b4b95716> in <module>()
#       3 np.random.seed(123)
#       4 d_top = np.random.normal(size=your_feedforward.shape)
# ----> 5 your_dw, your_db = conv2d_backward(d_top, x, w, b, pad, stride)
#       6 print(your_dw)
#       7 print('*'*50)
#
# ~/assignment2/ecbm4040/layer_funcs.py in conv2d_backward(d_top, x, w, b, pad, stride)
#     207     #                                                                     #
#     208     #######################################################################
# --> 209     raise NotImplementedError
#
# NotImplementedError:

# %% [markdown]
# ## Part 2: TensorFlow CNN

# %% [markdown]
# In this part we will construct the CNN in TensorFlow. To be more specific, we are going to implement a CNN similar to the LeNet structure.
#
# Tensorflow offers many useful resources and functions which help developers build the net in a high-level fashion, such as functions in the `layer` module. However, we will build the network by ourself for this homework for better understanding. By utilizing functions in `tf.nn` that exist for Neural Network structuring and training, we can build out our own layers and network modules rather quickly.
#
# Also, we will introduce a visualization tool called Tensorboard. You can use TensorBoard to visualize your TensorFlow graph, plot quantitative metrics about the execution of your graph, and show additional data that pass through it.
#
# Resources and References: <br>
# * [TensorBoard: Visualizing Learning](https://www.tensorflow.org/get_started/summaries_and_tensorboard)<br>
# * [Convolutional Neural Networks (LeNet) - DeepLearning 0.1 documentation](http://deeplearning.net/tutorial/lenet.html)<br>
# * [LeNet-5, convolutional neural networks](http://yann.lecun.com/exdb/lenet/)

# %% [markdown]
# ### Quick guide for Tensorboard
#
# Tensorboard is a powerful tool provided by TensorFlow. It allows developers to check their graph and trend of parameters. This guide will give you a basic under standing on how to set up Tensorboard graph in your code, start tensorboard on your local machine/GCP instance and how to access the interface.
#
# For complete instructions, check the official guide on Tensorflow web site [here](https://www.tensorflow.org/get_started/summaries_and_tensorboard).
#
# ### How to start tensorboard
#
# #### Local
#
# To start your Tensorboard on your local machine, you need to specify a log directory for the service to fetch the graph. For example, in your command line, type:
#
# ```shell
# $ tensorboard --logdir="~/log"
# ```
#
# Then, Tensorboard will start running. By default, it will be running on port 6006:
#
# ``` shell
# TensorBoard 0.1.6 at http://localhost:6006 (Press CTRL+C to quit)
# ```
#
# Make sure Tensorboard is running, you can visit http://localhost:6006 In your browser and you should be able to see the main page of Tensorboard. If the page is shown as below, it means Tensorboard is running correctly. The report is due to lack of event file, but we can just leave it there for now.
#
# ![Tensorboard_1](./ecbm4040/notebook_images/task3_2_1.png)
#
# #### GCP
#
# To set up the Tensorboard on GCP is the same as above. However, we're not able to check the Tensorboard UI directly through our browser. In order to visit the page through our local browser, we should link the port of our local machine to the port on GCP. It is similar to what we did previously for Jupyter Notebook.
#
# In the command line on your local machine, type:
#
# ```shell
# $ gcloud compute ssh --ssh-flag="-L 9999:localhost:9999 -L 9998:localhost:6006" "ecbm4040@YOUR_INSTANCE"
# ```
#
#  This will bind your port of your local machine to the port on GCP instance. In this case, your local port 9999 is binded with 9999 on GCP, while local port 9998 is binded with 6006 on GCP. You can change whatever port you like as long as it does not confilct with your local services.
#
# After connecting to GCP using the command, you will be able to see the result page.
#
#
#
# ### Export Tensorboard events into log directory
#
# To generate data files for Tensorboard, we should use class `tf.summary.FileWriter`. This class will save your network graph sturcuture and all the variable summary.
#
# For example, in `cnn_sample.py `, the file writer will save the graph and the summary into a directory based on the current timestamp. Here is the code snippet:
#
# ```python
# cur_model_name = 'lenet_{}'.format(int(time.time()))
# # ...
#
# # set up summary writer for tensorboard
# merge = tf.summary.merge_all()	# merge all the summary for variables for execution
# writer = tf.summary.FileWriter("log/{}".format(cur_model_name), sess.graph)
# ```
#
# The following code will save all the parameter summary and marked with iteration_total. These data will be displayed in the Tensorboard latter on.
#
# ```python
# # ... previous code ...
# # ...
# 				if iter_total % 100 == 0:
#                     # do validation
#                     valid_eve, merge_result = sess.run([eve, merge], feed_dict={xs: X_val, ys: y_val})
#                     valid_acc = 100 - valid_eve * 100 / y_val.shape[0]
#                     if verbose:
#                         print('{}/{} loss: {} validation accuracy : {}%'.format(
#                             batch_size * (itr + 1),
#                             X_train.shape[0],
#                             cur_loss,
#                             valid_acc))
#
#                     # save the merge result summary
#                     writer.add_summary(merge_result, iter_total)
# ```
#
#
#
# ### Check the graph and summary in Tensorboard
#
# After executing the program once, you should able to see the graph displayed in the tensorboard. You can zoom in or zoom out or click into the layer block to check all the variables and tensor operations.
#
# ![Tensorboard_2](./ecbm4040/notebook_images/task3_2_2.png)
#
# Also, you may able to check the trend of the variables and the distribution of those in Scalar, Distributions and Histograms. You may explore the tensorboard by yourself and take advantage to it for debuging the nerwork structure.

# %% [markdown]
# <span style="color:red">__TODO:__</span> You will try to achieve your own CNN model that has similar structure to LeNet, show the model graph in tensorboard, and get a model with **65%** or higher accuracy using the data we provide you.
#
# An example code is included in __ecbm4040/neuralnets/cnn_sample.py__. This sample is used as a guide line for how to build a Neural Net model in Tensorflow. Feel free to utilize or change the code we give you.

# %% [markdown]
# ### Load Data
# <p style="color:red">The following cell load the data for you. You don't need to change them.</p>

# %%
# Load the raw CIFAR-10 data.
X_train, y_train = load_data(mode='train')

# Data organizations:
# Train data: 49000 samples from original train set: 1~49000
# Validation data: 1000 samples from original train set: 49000~50000
num_training = 49000
num_validation = 1000

X_val = X_train[-num_validation:, :]
y_val = y_train[-num_validation:]

X_train = X_train[:num_training, :]
y_train = y_train[:num_training]

# Preprocessing: subtract the mean value across every dimension for training data, and reshape it to be RGB size
mean_image = np.mean(X_train, axis=0)
X_train = X_train.astype(np.float32) - mean_image.astype(np.float32)
X_val = X_val.astype(np.float32) - mean_image

X_train = X_train.reshape([-1,32,32,3])/255
X_val = X_val.reshape([-1,32,32,3])/255

print('Train data shape: ', X_train.shape)
print('Train labels shape: ', y_train.shape)
print('Validation data shape: ', X_val.shape)
print('Validation labels shape: ', y_val.shape)
# Out:
# ./data/cifar-10-python.tar.gz already exists. Begin extracting...
# Train data shape:  (49000, 32, 32, 3)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 32, 32, 3)
# Validation labels shape:  (1000,)

# %% [markdown]
# ### CNN model example

# %%
from ecbm4040.neuralnets.cnn_sample import training
tf.reset_default_graph()
training(X_train, y_train, X_val, y_val, 
         conv_featmap=[6],
         fc_units=[84],
         conv_kernel_size=[5],
         pooling_size=[2],
         l2_norm=0.01,
         seed=235,
         learning_rate=1e-2,
         epoch=10,
         batch_size=245,
         verbose=False,
         pre_trained_model=None)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-192b26195f0c> in <module>()
#       1 from ecbm4040.neuralnets.cnn_sample import training
# ----> 2 tf.reset_default_graph()
#       3 training(X_train, y_train, X_val, y_val,
#       4          conv_featmap=[6],
#       5          fc_units=[84],
#
# NameError: name 'tf' is not defined

# %% [markdown]
# ### Show the model structure graph

# %%
# show the graph
from ecbm4040.neuralnets.cnn_jupyter_tensorboard import show_graph 
tf.reset_default_graph()
with tf.Session() as sess:
    saver = tf.train.import_meta_graph('model/lenet_example.meta')
    graph = tf.get_default_graph()
    show_graph(graph)

# %% [markdown]
# ### Custom CNN model

# %% [markdown]
# <span style="color:red">__TODO:__</span>
# 1. Complete the your own CNN in __ecbm4040/neuralnets/cnn.py__ with at least **65%** accuracy.
# 2. Print out the training process and the best validation accuracy, save the `.meta` model in __model/__ folder.
# 3. Attatch a screen shot of your tensorboard graph in the markdown cell below. Double click the cell and replace the example image with your own image. Here is a [Markdown Cheetsheet](https://github.com/adam-p/markdown-here/wiki/Markdown-Cheatsheet#images) that may also help.
#
# __Hint__:
# 1. You can copy and edit the code from `cnn_sample.py`
# 2. The techniques in task-1 and task-2 will help. Check the corresponding functions in Tensorflow.

# %%
from ecbm4040.neuralnets.cnn import my_training
tf.reset_default_graph()

kernel_sizes = [2, 5 ,10]
l2_penalties = [.00001, .0001 , .001, .01]
learning_rates = [1e-4, 1e-2, 1e-1]
batch_sizes    = [75, 150, 250, 400]
pooling_size   = [1, 2, 5, 7, 10]
conv_features  = [ 3, 6, 10 ]

results = list()
parameters = list()

for i in range(20):
    
    tf.reset_default_graph()
    k = np.random.choice(kernel_sizes)
    l = np.random.choice(l2_penalties)
    r = np.random.choice(learning_rates)
    b = np.random.choice(batch_sizes)
    p = np.random.choice(pooling_size)
    f = np.random.choice(conv_features)

    print('iteration ' + str(i) + ': \n')
    print('kernel size: ' + str(k)+ '\n')
    print('penalty: ' + str(l)+ '\n')
    print('learning rate: ' + str(r)+ '\n')
    print('batch size: ' + str(b)+ '\n')


    result , cache = my_training(X_train, y_train, X_val, y_val, 
             conv_featmap=[f],
             fc_units=[128, 84],
             conv_kernel_size=[k],
             pooling_size=[p],
             l2_norm= r,
             seed=235,
             use_adam = True,
             learning_rate= l,
             epoch=20,
             batch_size=b,
             verbose=False,
             pre_trained_model=None)
    
    results.append(result)
    parameters.append(cache)
# Out:
# iteration 0:
#
# kernel size: 10
#
# penalty: 0.01
#
# learning rate: 0.0001
#
# batch size: 400
#
# Building my LeNet. Parameters:
# conv_featmap=[6]
# fc_units=[128, 84]
# conv_kernel_size=[10]
# pooling_size=[2]
# l2_norm=0.0001
# seed=235
# learning_rate=0.01
# number of batches for training: 122
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 43.9%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 46.6%
# epoch 3
# Best validation accuracy! iteration:300 accuracy: 49.1%
# epoch 4
# Best validation accuracy! iteration:400 accuracy: 49.9%
# epoch 5
# Best validation accuracy! iteration:500 accuracy: 50.0%
# Best validation accuracy! iteration:600 accuracy: 50.2%
# epoch 6
# Best validation accuracy! iteration:700 accuracy: 53.3%
# epoch 7
# epoch 8
# Best validation accuracy! iteration:900 accuracy: 53.4%
# epoch 9
# epoch 10
# Best validation accuracy! iteration:1100 accuracy: 53.7%
# epoch 11
# Best validation accuracy! iteration:1300 accuracy: 55.0%
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# Traning ends. The best valid accuracy is 55.0. Model named lenet_1509720807.
# iteration 1:
#
# kernel size: 5
#
# penalty: 0.001
#
# learning rate: 0.01
#
# batch size: 250
#
# Building my LeNet. Parameters:
# conv_featmap=[10]
# fc_units=[128, 84]
# conv_kernel_size=[5]
# pooling_size=[2]
# l2_norm=0.01
# seed=235
# learning_rate=0.001
# number of batches for training: 196
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 40.4%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 47.9%
# Best validation accuracy! iteration:300 accuracy: 48.2%
# epoch 3
# Best validation accuracy! iteration:400 accuracy: 52.1%
# epoch 4
# Best validation accuracy! iteration:600 accuracy: 54.0%
# epoch 5
# Best validation accuracy! iteration:800 accuracy: 55.2%
# Best validation accuracy! iteration:900 accuracy: 56.2%
# epoch 6
# Best validation accuracy! iteration:1100 accuracy: 57.8%
# epoch 7
# Best validation accuracy! iteration:1200 accuracy: 57.9%
# epoch 8
# Best validation accuracy! iteration:1400 accuracy: 59.2%
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# Best validation accuracy! iteration:2300 accuracy: 60.2%
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# Best validation accuracy! iteration:3000 accuracy: 60.7%
# Best validation accuracy! iteration:3100 accuracy: 60.9%
# epoch 17
# Best validation accuracy! iteration:3300 accuracy: 61.7%
# epoch 18
# epoch 19
# Best validation accuracy! iteration:3700 accuracy: 62.1%
# epoch 20
# Traning ends. The best valid accuracy is 62.1. Model named lenet_1509720846.
# iteration 2:
#
# kernel size: 5
#
# penalty: 0.01
#
# learning rate: 0.01
#
# batch size: 75
#
# Building my LeNet. Parameters:
# conv_featmap=[6]
# fc_units=[128, 84]
# conv_kernel_size=[5]
# pooling_size=[7]
# l2_norm=0.01
# seed=235
# learning_rate=0.01
# number of batches for training: 653
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 29.799999999999997%
# Best validation accuracy! iteration:200 accuracy: 34.8%
# Best validation accuracy! iteration:400 accuracy: 38.5%
# epoch 2
# Best validation accuracy! iteration:1000 accuracy: 39.2%
# Best validation accuracy! iteration:1100 accuracy: 41.4%
# epoch 3
# Best validation accuracy! iteration:1500 accuracy: 42.0%
# Best validation accuracy! iteration:1600 accuracy: 42.5%
# Best validation accuracy! iteration:1700 accuracy: 42.6%
# epoch 4
# Best validation accuracy! iteration:2400 accuracy: 44.4%
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# Best validation accuracy! iteration:5700 accuracy: 44.9%
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# Best validation accuracy! iteration:9700 accuracy: 45.5%
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# Traning ends. The best valid accuracy is 45.5. Model named lenet_1509720894.
# iteration 3:
#
# kernel size: 2
#
# penalty: 0.0001
#
# learning rate: 0.0001
#
# batch size: 150
#
# Building my LeNet. Parameters:
# conv_featmap=[10]
# fc_units=[128, 84]
# conv_kernel_size=[2]
# pooling_size=[2]
# l2_norm=0.0001
# seed=235
# learning_rate=0.0001
# number of batches for training: 326
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 34.2%
# Best validation accuracy! iteration:200 accuracy: 38.3%
# Best validation accuracy! iteration:300 accuracy: 40.7%
# epoch 2
# Best validation accuracy! iteration:400 accuracy: 44.3%
# Best validation accuracy! iteration:500 accuracy: 46.0%
# Best validation accuracy! iteration:600 accuracy: 48.0%
# epoch 3
# Best validation accuracy! iteration:700 accuracy: 50.0%
# epoch 4
# Best validation accuracy! iteration:1000 accuracy: 50.5%
# Best validation accuracy! iteration:1100 accuracy: 50.6%
# Best validation accuracy! iteration:1200 accuracy: 51.1%
# Best validation accuracy! iteration:1300 accuracy: 52.0%
# epoch 5
# Best validation accuracy! iteration:1400 accuracy: 52.9%
# Best validation accuracy! iteration:1500 accuracy: 53.7%
# Best validation accuracy! iteration:1600 accuracy: 53.8%
# epoch 6
# epoch 7
# Best validation accuracy! iteration:2000 accuracy: 53.9%
# Best validation accuracy! iteration:2100 accuracy: 54.1%
# Best validation accuracy! iteration:2200 accuracy: 54.3%
# epoch 8
# epoch 9
# Best validation accuracy! iteration:2700 accuracy: 55.7%
# epoch 10
# epoch 11
# Best validation accuracy! iteration:3300 accuracy: 55.8%
# epoch 12
# Best validation accuracy! iteration:3600 accuracy: 56.2%
# Best validation accuracy! iteration:3700 accuracy: 56.6%
# epoch 13
# epoch 14
# Best validation accuracy! iteration:4400 accuracy: 57.0%
# epoch 15
# Best validation accuracy! iteration:4600 accuracy: 57.4%
# Best validation accuracy! iteration:4700 accuracy: 57.5%
# epoch 16
# Best validation accuracy! iteration:5200 accuracy: 57.7%
# epoch 17
# epoch 18
# epoch 19
# Best validation accuracy! iteration:6100 accuracy: 58.1%
# epoch 20
# Best validation accuracy! iteration:6300 accuracy: 58.2%
# Traning ends. The best valid accuracy is 58.2. Model named lenet_1509720962.
# iteration 4:
#
# kernel size: 10
#
# penalty: 0.0001
#
# learning rate: 0.01
#
# batch size: 150
#
# Building my LeNet. Parameters:
# conv_featmap=[10]
# fc_units=[128, 84]
# conv_kernel_size=[10]
# pooling_size=[10]
# l2_norm=0.01
# seed=235
# learning_rate=0.0001
# number of batches for training: 326
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 15.799999999999997%
# Best validation accuracy! iteration:200 accuracy: 20.400000000000006%
# Best validation accuracy! iteration:300 accuracy: 24.0%
# epoch 2
# Best validation accuracy! iteration:400 accuracy: 26.599999999999994%
# Best validation accuracy! iteration:500 accuracy: 27.0%
# Best validation accuracy! iteration:600 accuracy: 28.599999999999994%
# epoch 3
# Best validation accuracy! iteration:700 accuracy: 30.599999999999994%
# Best validation accuracy! iteration:800 accuracy: 30.900000000000006%
# Best validation accuracy! iteration:900 accuracy: 31.099999999999994%
# epoch 4
# Best validation accuracy! iteration:1000 accuracy: 32.3%
# Best validation accuracy! iteration:1100 accuracy: 32.400000000000006%
# Best validation accuracy! iteration:1200 accuracy: 33.599999999999994%
# Best validation accuracy! iteration:1300 accuracy: 33.8%
# epoch 5
# epoch 6
# Best validation accuracy! iteration:1800 accuracy: 34.400000000000006%
# epoch 7
# Best validation accuracy! iteration:2000 accuracy: 34.8%
# epoch 8
# Best validation accuracy! iteration:2300 accuracy: 35.400000000000006%
# Best validation accuracy! iteration:2500 accuracy: 36.1%
# epoch 9
# epoch 10
# Best validation accuracy! iteration:3100 accuracy: 36.8%
# epoch 11
# epoch 12
# Best validation accuracy! iteration:3800 accuracy: 37.1%
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# Best validation accuracy! iteration:5600 accuracy: 37.3%
# epoch 19
# Best validation accuracy! iteration:5900 accuracy: 37.5%
# Best validation accuracy! iteration:6100 accuracy: 37.7%
# epoch 20
# Best validation accuracy! iteration:6200 accuracy: 38.1%
# Traning ends. The best valid accuracy is 38.1. Model named lenet_1509721012.
# iteration 5:
#
# kernel size: 2
#
# penalty: 0.01
#
# learning rate: 0.1
#
# batch size: 250
#
# Building my LeNet. Parameters:
# conv_featmap=[6]
# fc_units=[128, 84]
# conv_kernel_size=[2]
# pooling_size=[1]
# l2_norm=0.1
# seed=235
# learning_rate=0.01
# number of batches for training: 196
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 26.599999999999994%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 29.599999999999994%
# epoch 3
# epoch 4
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# Best validation accuracy! iteration:1400 accuracy: 30.299999999999997%
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# Traning ends. The best valid accuracy is 30.299999999999997. Model named lenet_1509721074.
# iteration 6:
#
# kernel size: 5
#
# penalty: 0.0001
#
# learning rate: 0.0001
#
# batch size: 400
#
# Building my LeNet. Parameters:
# conv_featmap=[3]
# fc_units=[128, 84]
# conv_kernel_size=[5]
# pooling_size=[10]
# l2_norm=0.0001
# seed=235
# learning_rate=0.0001
# number of batches for training: 122
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 17.700000000000003%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 18.400000000000006%
# epoch 3
# Best validation accuracy! iteration:300 accuracy: 20.900000000000006%
# epoch 4
# Best validation accuracy! iteration:400 accuracy: 21.900000000000006%
# epoch 5
# Best validation accuracy! iteration:500 accuracy: 22.200000000000003%
# Best validation accuracy! iteration:600 accuracy: 24.0%
# epoch 6
# epoch 7
# Best validation accuracy! iteration:800 accuracy: 24.400000000000006%
# epoch 8
# Best validation accuracy! iteration:900 accuracy: 25.0%
# epoch 9
# Best validation accuracy! iteration:1000 accuracy: 25.599999999999994%
# epoch 10
# Best validation accuracy! iteration:1100 accuracy: 25.700000000000003%
# Best validation accuracy! iteration:1200 accuracy: 25.799999999999997%
# epoch 11
# Best validation accuracy! iteration:1300 accuracy: 26.0%
# epoch 12
# Best validation accuracy! iteration:1400 accuracy: 26.799999999999997%
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# Best validation accuracy! iteration:2000 accuracy: 27.200000000000003%
# epoch 18
# epoch 19
# epoch 20
# Traning ends. The best valid accuracy is 27.200000000000003. Model named lenet_1509721113.
# iteration 7:
#
# kernel size: 10
#
# penalty: 0.01
#
# learning rate: 0.01
#
# batch size: 75
#
# Building my LeNet. Parameters:
# conv_featmap=[10]
# fc_units=[128, 84]
# conv_kernel_size=[10]
# pooling_size=[5]
# l2_norm=0.01
# seed=235
# learning_rate=0.01
# number of batches for training: 653
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 29.900000000000006%
# Best validation accuracy! iteration:200 accuracy: 35.900000000000006%
# Best validation accuracy! iteration:300 accuracy: 37.6%
# Best validation accuracy! iteration:400 accuracy: 38.0%
# Best validation accuracy! iteration:500 accuracy: 39.5%
# Best validation accuracy! iteration:600 accuracy: 41.9%
# epoch 2
# Best validation accuracy! iteration:700 accuracy: 43.4%
# Best validation accuracy! iteration:800 accuracy: 43.5%
# Best validation accuracy! iteration:900 accuracy: 43.6%
# epoch 3
# Best validation accuracy! iteration:1500 accuracy: 45.3%
# Best validation accuracy! iteration:1600 accuracy: 45.4%
# epoch 4
# Best validation accuracy! iteration:2100 accuracy: 46.3%
# Best validation accuracy! iteration:2600 accuracy: 47.0%
# epoch 5
# Best validation accuracy! iteration:3000 accuracy: 49.2%
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# Best validation accuracy! iteration:7900 accuracy: 50.1%
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# Traning ends. The best valid accuracy is 50.1. Model named lenet_1509721143.
# iteration 8:
#
# kernel size: 5
#
# penalty: 0.01
#
# learning rate: 0.0001
#
# batch size: 400
#
# Building my LeNet. Parameters:
# conv_featmap=[10]
# fc_units=[128, 84]
# conv_kernel_size=[5]
# pooling_size=[10]
# l2_norm=0.0001
# seed=235
# learning_rate=0.01
# number of batches for training: 122
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 32.7%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 35.900000000000006%
# epoch 3
# Best validation accuracy! iteration:300 accuracy: 38.6%
# epoch 4
# epoch 5
# Best validation accuracy! iteration:500 accuracy: 42.0%
# Best validation accuracy! iteration:600 accuracy: 42.2%
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# epoch 10
# Best validation accuracy! iteration:1200 accuracy: 45.2%
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# Best validation accuracy! iteration:1800 accuracy: 45.3%
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# Traning ends. The best valid accuracy is 45.3. Model named lenet_1509721228.
# iteration 9:
#
# kernel size: 10
#
# penalty: 0.01
#
# learning rate: 0.0001
#
# batch size: 400
#
# Building my LeNet. Parameters:
# conv_featmap=[6]
# fc_units=[128, 84]
# conv_kernel_size=[10]
# pooling_size=[10]
# l2_norm=0.0001
# seed=235
# learning_rate=0.01
# number of batches for training: 122
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 35.099999999999994%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 36.4%
# epoch 3
# Best validation accuracy! iteration:300 accuracy: 38.0%
# epoch 4
# Best validation accuracy! iteration:400 accuracy: 42.0%
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# Best validation accuracy! iteration:1700 accuracy: 42.3%
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# Best validation accuracy! iteration:2100 accuracy: 42.5%
# epoch 19
# Best validation accuracy! iteration:2200 accuracy: 42.9%
# epoch 20
# Traning ends. The best valid accuracy is 42.9. Model named lenet_1509721267.
# iteration 10:
#
# kernel size: 2
#
# penalty: 0.01
#
# learning rate: 0.0001
#
# batch size: 250
#
# Building my LeNet. Parameters:
# conv_featmap=[3]
# fc_units=[128, 84]
# conv_kernel_size=[2]
# pooling_size=[2]
# l2_norm=0.0001
# seed=235
# learning_rate=0.01
# number of batches for training: 196
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 44.1%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 47.7%
# Best validation accuracy! iteration:300 accuracy: 48.7%
# epoch 3
# epoch 4
# Best validation accuracy! iteration:600 accuracy: 49.7%
# epoch 5
# Best validation accuracy! iteration:800 accuracy: 50.7%
# Best validation accuracy! iteration:900 accuracy: 51.5%
# epoch 6
# epoch 7
# epoch 8
# Best validation accuracy! iteration:1400 accuracy: 51.7%
# Best validation accuracy! iteration:1500 accuracy: 52.5%
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# Traning ends. The best valid accuracy is 52.5. Model named lenet_1509721304.
# iteration 11:
#
# kernel size: 5
#
# penalty: 0.01
#
# learning rate: 0.01
#
# batch size: 150
#
# Building my LeNet. Parameters:
# conv_featmap=[6]
# fc_units=[128, 84]
# conv_kernel_size=[5]
# pooling_size=[7]
# l2_norm=0.01
# seed=235
# learning_rate=0.01
# number of batches for training: 326
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 33.2%
# Best validation accuracy! iteration:200 accuracy: 39.1%
# epoch 2
# Best validation accuracy! iteration:500 accuracy: 39.2%
# Best validation accuracy! iteration:600 accuracy: 40.0%
# epoch 3
# Best validation accuracy! iteration:700 accuracy: 40.3%
# Best validation accuracy! iteration:800 accuracy: 41.8%
# epoch 4
# Best validation accuracy! iteration:1100 accuracy: 44.2%
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# Best validation accuracy! iteration:2900 accuracy: 44.4%
# epoch 10
# epoch 11
# epoch 12
# Best validation accuracy! iteration:3900 accuracy: 44.9%
# epoch 13
# Best validation accuracy! iteration:4200 accuracy: 46.1%
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# Traning ends. The best valid accuracy is 46.1. Model named lenet_1509721333.
# iteration 12:
#
# kernel size: 5
#
# penalty: 1e-05
#
# learning rate: 0.0001
#
# batch size: 250
#
# Building my LeNet. Parameters:
# conv_featmap=[3]
# fc_units=[128, 84]
# conv_kernel_size=[5]
# pooling_size=[10]
# l2_norm=0.0001
# seed=235
# learning_rate=1e-05
# number of batches for training: 196
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 11.799999999999997%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 12.400000000000006%
# Best validation accuracy! iteration:300 accuracy: 13.0%
# epoch 3
# Best validation accuracy! iteration:400 accuracy: 14.099999999999994%
# Best validation accuracy! iteration:500 accuracy: 14.400000000000006%
# epoch 4
# Best validation accuracy! iteration:600 accuracy: 14.700000000000003%
# Best validation accuracy! iteration:700 accuracy: 14.799999999999997%
# epoch 5
# Best validation accuracy! iteration:800 accuracy: 14.900000000000006%
# Best validation accuracy! iteration:900 accuracy: 15.200000000000003%
# epoch 6
# Best validation accuracy! iteration:1000 accuracy: 16.400000000000006%
# Best validation accuracy! iteration:1100 accuracy: 18.099999999999994%
# epoch 7
# Best validation accuracy! iteration:1200 accuracy: 18.799999999999997%
# Best validation accuracy! iteration:1300 accuracy: 20.0%
# epoch 8
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# Best validation accuracy! iteration:3000 accuracy: 20.200000000000003%
# epoch 17
# Best validation accuracy! iteration:3200 accuracy: 20.400000000000006%
# Best validation accuracy! iteration:3300 accuracy: 20.5%
# epoch 18
# epoch 19
# Best validation accuracy! iteration:3700 accuracy: 20.700000000000003%
# epoch 20
# Best validation accuracy! iteration:3900 accuracy: 20.900000000000006%
# Traning ends. The best valid accuracy is 20.900000000000006. Model named lenet_1509721380.
# iteration 13:
#
# kernel size: 2
#
# penalty: 0.01
#
# learning rate: 0.01
#
# batch size: 75
#
# Building my LeNet. Parameters:
# conv_featmap=[6]
# fc_units=[128, 84]
# conv_kernel_size=[2]
# pooling_size=[1]
# l2_norm=0.01
# seed=235
# learning_rate=0.01
# number of batches for training: 653
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 27.200000000000003%
# Best validation accuracy! iteration:200 accuracy: 34.099999999999994%
# Best validation accuracy! iteration:300 accuracy: 40.6%
# Best validation accuracy! iteration:400 accuracy: 45.8%
# Best validation accuracy! iteration:500 accuracy: 48.7%
# epoch 2
# Best validation accuracy! iteration:1200 accuracy: 49.7%
# epoch 3
# Best validation accuracy! iteration:1500 accuracy: 50.1%
# epoch 4
# Best validation accuracy! iteration:2000 accuracy: 51.5%
# Best validation accuracy! iteration:2400 accuracy: 51.9%
# epoch 5
# Best validation accuracy! iteration:2800 accuracy: 53.5%
# Best validation accuracy! iteration:2900 accuracy: 53.7%
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# Best validation accuracy! iteration:10100 accuracy: 54.6%
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# Traning ends. The best valid accuracy is 54.6. Model named lenet_1509721416.
# iteration 14:
#
# kernel size: 10
#
# penalty: 0.001
#
# learning rate: 0.0001
#
# batch size: 250
#
# Building my LeNet. Parameters:
# conv_featmap=[10]
# fc_units=[128, 84]
# conv_kernel_size=[10]
# pooling_size=[10]
# l2_norm=0.0001
# seed=235
# learning_rate=0.001
# number of batches for training: 196
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 31.5%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 34.2%
# Best validation accuracy! iteration:300 accuracy: 37.4%
# epoch 3
# epoch 4
# Best validation accuracy! iteration:600 accuracy: 38.5%
# epoch 5
# Best validation accuracy! iteration:800 accuracy: 39.6%
# Best validation accuracy! iteration:900 accuracy: 39.8%
# epoch 6
# Best validation accuracy! iteration:1000 accuracy: 40.1%
# Best validation accuracy! iteration:1100 accuracy: 43.4%
# epoch 7
# epoch 8
# Best validation accuracy! iteration:1400 accuracy: 44.8%
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# Best validation accuracy! iteration:2400 accuracy: 45.1%
# epoch 14
# epoch 15
# epoch 16
# Best validation accuracy! iteration:3000 accuracy: 46.4%
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# Traning ends. The best valid accuracy is 46.4. Model named lenet_1509721494.
# iteration 15:
#
# kernel size: 5
#
# penalty: 0.0001
#
# learning rate: 0.01
#
# batch size: 150
#
# Building my LeNet. Parameters:
# conv_featmap=[3]
# fc_units=[128, 84]
# conv_kernel_size=[5]
# pooling_size=[5]
# l2_norm=0.01
# seed=235
# learning_rate=0.0001
# number of batches for training: 326
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 16.299999999999997%
# Best validation accuracy! iteration:200 accuracy: 20.599999999999994%
# Best validation accuracy! iteration:300 accuracy: 22.0%
# epoch 2
# Best validation accuracy! iteration:400 accuracy: 24.799999999999997%
# Best validation accuracy! iteration:600 accuracy: 25.900000000000006%
# epoch 3
# Best validation accuracy! iteration:700 accuracy: 27.099999999999994%
# Best validation accuracy! iteration:800 accuracy: 28.400000000000006%
# epoch 4
# Best validation accuracy! iteration:1000 accuracy: 29.0%
# Best validation accuracy! iteration:1100 accuracy: 29.5%
# Best validation accuracy! iteration:1200 accuracy: 30.299999999999997%
# epoch 5
# Best validation accuracy! iteration:1500 accuracy: 31.0%
# Best validation accuracy! iteration:1600 accuracy: 31.900000000000006%
# epoch 6
# Best validation accuracy! iteration:1700 accuracy: 33.5%
# epoch 7
# Best validation accuracy! iteration:2200 accuracy: 33.7%
# epoch 8
# Best validation accuracy! iteration:2300 accuracy: 34.599999999999994%
# epoch 9
# Best validation accuracy! iteration:2800 accuracy: 35.400000000000006%
# epoch 10
# Best validation accuracy! iteration:3200 accuracy: 35.599999999999994%
# epoch 11
# Best validation accuracy! iteration:3400 accuracy: 36.4%
# Best validation accuracy! iteration:3500 accuracy: 36.6%
# epoch 12
# Best validation accuracy! iteration:3800 accuracy: 37.0%
# epoch 13
# Best validation accuracy! iteration:4000 accuracy: 37.2%
# Best validation accuracy! iteration:4100 accuracy: 37.9%
# epoch 14
# Best validation accuracy! iteration:4300 accuracy: 38.0%
# epoch 15
# epoch 16
# Best validation accuracy! iteration:4900 accuracy: 38.3%
# Best validation accuracy! iteration:5100 accuracy: 39.2%
# epoch 17
# epoch 18
# Best validation accuracy! iteration:5600 accuracy: 40.3%
# Best validation accuracy! iteration:5700 accuracy: 41.4%
# epoch 19
# Best validation accuracy! iteration:6100 accuracy: 42.0%
# epoch 20
# Traning ends. The best valid accuracy is 42.0. Model named lenet_1509721546.
# iteration 16:
#
# kernel size: 2
#
# penalty: 0.01
#
# learning rate: 0.1
#
# batch size: 150
#
# Building my LeNet. Parameters:
# conv_featmap=[6]
# fc_units=[128, 84]
# conv_kernel_size=[2]
# pooling_size=[2]
# l2_norm=0.1
# seed=235
# learning_rate=0.01
# number of batches for training: 326
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 30.900000000000006%
# epoch 2
# epoch 3
# epoch 4
# Best validation accuracy! iteration:1000 accuracy: 31.599999999999994%
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# Best validation accuracy! iteration:2400 accuracy: 33.3%
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# Best validation accuracy! iteration:3800 accuracy: 34.0%
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# Traning ends. The best valid accuracy is 34.0. Model named lenet_1509721591.
# iteration 17:
#
# kernel size: 10
#
# penalty: 0.0001
#
# learning rate: 0.1
#
# batch size: 150
#
# Building my LeNet. Parameters:
# conv_featmap=[6]
# fc_units=[128, 84]
# conv_kernel_size=[10]
# pooling_size=[10]
# l2_norm=0.1
# seed=235
# learning_rate=0.0001
# number of batches for training: 326
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 13.900000000000006%
# Best validation accuracy! iteration:200 accuracy: 15.799999999999997%
# Best validation accuracy! iteration:300 accuracy: 17.5%
# epoch 2
# Best validation accuracy! iteration:400 accuracy: 19.099999999999994%
# epoch 3
# epoch 4
# epoch 5
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# Traning ends. The best valid accuracy is 19.099999999999994. Model named lenet_1509721633.
# iteration 18:
#
# kernel size: 5
#
# penalty: 0.01
#
# learning rate: 0.01
#
# batch size: 250
#
# Building my LeNet. Parameters:
# conv_featmap=[3]
# fc_units=[128, 84]
# conv_kernel_size=[5]
# pooling_size=[1]
# l2_norm=0.01
# seed=235
# learning_rate=0.01
# number of batches for training: 196
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 38.9%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 41.6%
# Best validation accuracy! iteration:300 accuracy: 44.8%
# epoch 3
# Best validation accuracy! iteration:400 accuracy: 45.7%
# epoch 4
# Best validation accuracy! iteration:600 accuracy: 47.3%
# epoch 5
# epoch 6
# Best validation accuracy! iteration:1000 accuracy: 48.7%
# epoch 7
# Best validation accuracy! iteration:1200 accuracy: 49.2%
# epoch 8
# Best validation accuracy! iteration:1400 accuracy: 51.9%
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# Best validation accuracy! iteration:3100 accuracy: 52.0%
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# Traning ends. The best valid accuracy is 52.0. Model named lenet_1509721685.
# iteration 19:
#
# kernel size: 2
#
# penalty: 0.0001
#
# learning rate: 0.0001
#
# batch size: 400
#
# Building my LeNet. Parameters:
# conv_featmap=[10]
# fc_units=[128, 84]
# conv_kernel_size=[2]
# pooling_size=[1]
# l2_norm=0.0001
# seed=235
# learning_rate=0.0001
# number of batches for training: 122
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 36.7%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 45.6%
# epoch 3
# Best validation accuracy! iteration:300 accuracy: 46.9%
# epoch 4
# Best validation accuracy! iteration:400 accuracy: 48.1%
# epoch 5
# Best validation accuracy! iteration:500 accuracy: 49.3%
# epoch 6
# Best validation accuracy! iteration:700 accuracy: 50.2%
# epoch 7
# Best validation accuracy! iteration:800 accuracy: 51.8%
# epoch 8
# Best validation accuracy! iteration:900 accuracy: 51.9%
# epoch 9
# epoch 10
# Best validation accuracy! iteration:1100 accuracy: 52.3%
# Best validation accuracy! iteration:1200 accuracy: 52.5%
# epoch 11
# Best validation accuracy! iteration:1300 accuracy: 53.2%
# epoch 12
# Best validation accuracy! iteration:1400 accuracy: 55.5%
# epoch 13
# epoch 14
# Best validation accuracy! iteration:1600 accuracy: 55.7%
# epoch 15
# Best validation accuracy! iteration:1800 accuracy: 55.9%
# epoch 16
# epoch 17
# Best validation accuracy! iteration:2000 accuracy: 56.2%
# epoch 18
# epoch 19
# Best validation accuracy! iteration:2300 accuracy: 56.9%
# epoch 20
# Best validation accuracy! iteration:2400 accuracy: 57.6%
# Traning ends. The best valid accuracy is 57.6. Model named lenet_1509721725.

# %%
results
# Out:
# [55.0,
#  62.100000000000001,
#  45.5,
#  58.200000000000003,
#  38.100000000000001,
#  30.299999999999997,
#  27.200000000000003,
#  50.100000000000001,
#  45.299999999999997,
#  42.899999999999999,
#  52.5,
#  46.100000000000001,
#  20.900000000000006,
#  54.600000000000001,
#  46.399999999999999,
#  42.0,
#  34.0,
#  19.099999999999994,
#  52.0,
#  57.600000000000001]

# %%
best = [i for i, r in enumerate(results) if r == max(results)]

print(results[best[0]])
parameters[best[0]]
# Out:
# 62.1
# ['lenet_1509720846',
#  [10],
#  [128, 84],
#  [5],
#  [2],
#  0.01,
#  235,
#  0.001,
#  20,
#  250,
#  False,
#  None,
#  True]

# %%
kernel_sizes = [4, 5, 6]
l2_penalties = [.00001, .0001]
learning_rates = [1e-3, 1e-2, 1e-1]
batch_sizes    = [ 200, 250, 300]
pooling_size   = [1, 2, 3]
conv_features  = [ 8 ,10 , 12 ]

tune_results = list()
tune_parameters = list()
for i in range(10):
    
    tf.reset_default_graph()
    k = np.random.choice(kernel_sizes)
    l = np.random.choice(l2_penalties)
    r = np.random.choice(learning_rates)
    b = np.random.choice(batch_sizes)
    p = np.random.choice(pooling_size)
    f = np.random.choice(conv_features)

    print('iteration ' + str(i) + ': \n')
    print('kernel size: ' + str(k)+ '\n')
    print('penalty: ' + str(l)+ '\n')
    print('learning rate: ' + str(r)+ '\n')
    print('batch size: ' + str(b)+ '\n')


    result , cache = my_training(X_train, y_train, X_val, y_val, 
             conv_featmap=[f],
             fc_units=[128, 84],
             conv_kernel_size=[k],
             pooling_size=[p],
             l2_norm= r,
             seed=235,
             use_adam = True,
             learning_rate= l,
             epoch=20,
             batch_size=b,
             verbose=False,
             pre_trained_model=None)
    
    tune_results.append(result)
    tune_parameters.append(cache)
# Out:
# iteration 0:
#
# kernel size: 5
#
# penalty: 1e-05
#
# learning rate: 0.001
#
# batch size: 300
#
# Building my LeNet. Parameters:
# conv_featmap=[10]
# fc_units=[128, 84]
# conv_kernel_size=[5]
# pooling_size=[3]
# l2_norm=0.001
# seed=235
# learning_rate=1e-05
# number of batches for training: 163
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 18.299999999999997%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 22.400000000000006%
# Best validation accuracy! iteration:300 accuracy: 24.400000000000006%
# epoch 3
# Best validation accuracy! iteration:400 accuracy: 25.700000000000003%
# epoch 4
# Best validation accuracy! iteration:500 accuracy: 26.599999999999994%
# Best validation accuracy! iteration:600 accuracy: 27.200000000000003%
# epoch 5
# Best validation accuracy! iteration:700 accuracy: 28.299999999999997%
# Best validation accuracy! iteration:800 accuracy: 28.599999999999994%
# epoch 6
# Best validation accuracy! iteration:900 accuracy: 29.299999999999997%
# epoch 7
# Best validation accuracy! iteration:1000 accuracy: 29.799999999999997%
# Best validation accuracy! iteration:1100 accuracy: 30.5%
# epoch 8
# Best validation accuracy! iteration:1200 accuracy: 32.0%
# epoch 9
# epoch 10
# Best validation accuracy! iteration:1500 accuracy: 33.099999999999994%
# Best validation accuracy! iteration:1600 accuracy: 33.3%
# epoch 11
# epoch 12
# Best validation accuracy! iteration:1800 accuracy: 33.5%
# Best validation accuracy! iteration:1900 accuracy: 34.3%
# epoch 13
# epoch 14
# Best validation accuracy! iteration:2200 accuracy: 34.599999999999994%
# epoch 15
# Best validation accuracy! iteration:2400 accuracy: 34.7%
# epoch 16
# Best validation accuracy! iteration:2500 accuracy: 35.8%
# Best validation accuracy! iteration:2600 accuracy: 35.900000000000006%
# epoch 17
# epoch 18
# Best validation accuracy! iteration:2800 accuracy: 36.3%
# epoch 19
# Best validation accuracy! iteration:3000 accuracy: 36.9%
# epoch 20
# Best validation accuracy! iteration:3200 accuracy: 37.0%
# Traning ends. The best valid accuracy is 37.0. Model named lenet_1509723213.
# iteration 1:
#
# kernel size: 6
#
# penalty: 0.0001
#
# learning rate: 0.1
#
# batch size: 200
#
# Building my LeNet. Parameters:
# conv_featmap=[8]
# fc_units=[128, 84]
# conv_kernel_size=[6]
# pooling_size=[2]
# l2_norm=0.1
# seed=235
# learning_rate=0.0001
# number of batches for training: 245
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 29.200000000000003%
# Best validation accuracy! iteration:200 accuracy: 33.3%
# epoch 2
# Best validation accuracy! iteration:300 accuracy: 34.7%
# Best validation accuracy! iteration:400 accuracy: 40.6%
# epoch 3
# epoch 4
# Best validation accuracy! iteration:800 accuracy: 41.4%
# epoch 5
# Best validation accuracy! iteration:1000 accuracy: 42.8%
# epoch 6
# Best validation accuracy! iteration:1300 accuracy: 42.9%
# epoch 7
# epoch 8
# epoch 9
# Best validation accuracy! iteration:2200 accuracy: 43.1%
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# Traning ends. The best valid accuracy is 43.1. Model named lenet_1509723257.
# iteration 2:
#
# kernel size: 4
#
# penalty: 1e-05
#
# learning rate: 0.001
#
# batch size: 250
#
# Building my LeNet. Parameters:
# conv_featmap=[8]
# fc_units=[128, 84]
# conv_kernel_size=[4]
# pooling_size=[2]
# l2_norm=0.001
# seed=235
# learning_rate=1e-05
# number of batches for training: 196
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 17.799999999999997%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 20.400000000000006%
# Best validation accuracy! iteration:300 accuracy: 23.5%
# epoch 3
# Best validation accuracy! iteration:400 accuracy: 27.0%
# Best validation accuracy! iteration:500 accuracy: 28.299999999999997%
# epoch 4
# Best validation accuracy! iteration:600 accuracy: 30.400000000000006%
# epoch 5
# Best validation accuracy! iteration:800 accuracy: 32.3%
# Best validation accuracy! iteration:900 accuracy: 32.599999999999994%
# epoch 6
# Best validation accuracy! iteration:1000 accuracy: 33.400000000000006%
# Best validation accuracy! iteration:1100 accuracy: 33.5%
# epoch 7
# Best validation accuracy! iteration:1200 accuracy: 33.599999999999994%
# Best validation accuracy! iteration:1300 accuracy: 34.900000000000006%
# epoch 8
# Best validation accuracy! iteration:1500 accuracy: 35.400000000000006%
# epoch 9
# Best validation accuracy! iteration:1600 accuracy: 35.900000000000006%
# Best validation accuracy! iteration:1700 accuracy: 36.5%
# epoch 10
# Best validation accuracy! iteration:1800 accuracy: 37.2%
# epoch 11
# Best validation accuracy! iteration:2000 accuracy: 37.6%
# epoch 12
# Best validation accuracy! iteration:2200 accuracy: 38.2%
# Best validation accuracy! iteration:2300 accuracy: 38.4%
# epoch 13
# Best validation accuracy! iteration:2400 accuracy: 38.8%
# epoch 14
# Best validation accuracy! iteration:2600 accuracy: 38.9%
# epoch 15
# Best validation accuracy! iteration:2900 accuracy: 39.4%
# epoch 16
# Best validation accuracy! iteration:3000 accuracy: 40.0%
# epoch 17
# Best validation accuracy! iteration:3200 accuracy: 40.4%
# epoch 18
# Best validation accuracy! iteration:3400 accuracy: 41.1%
# epoch 19
# Best validation accuracy! iteration:3600 accuracy: 41.3%
# epoch 20
# Best validation accuracy! iteration:3800 accuracy: 41.6%
# Traning ends. The best valid accuracy is 41.6. Model named lenet_1509723305.
# iteration 3:
#
# kernel size: 6
#
# penalty: 1e-05
#
# learning rate: 0.001
#
# batch size: 200
#
# Building my LeNet. Parameters:
# conv_featmap=[12]
# fc_units=[128, 84]
# conv_kernel_size=[6]
# pooling_size=[2]
# l2_norm=0.001
# seed=235
# learning_rate=1e-05
# number of batches for training: 245
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 17.599999999999994%
# Best validation accuracy! iteration:200 accuracy: 23.0%
# epoch 2
# Best validation accuracy! iteration:300 accuracy: 28.900000000000006%
# Best validation accuracy! iteration:400 accuracy: 29.400000000000006%
# epoch 3
# Best validation accuracy! iteration:500 accuracy: 31.400000000000006%
# Best validation accuracy! iteration:600 accuracy: 32.2%
# Best validation accuracy! iteration:700 accuracy: 32.7%
# epoch 4
# Best validation accuracy! iteration:800 accuracy: 33.2%
# epoch 5
# Best validation accuracy! iteration:1000 accuracy: 33.900000000000006%
# Best validation accuracy! iteration:1100 accuracy: 34.3%
# Best validation accuracy! iteration:1200 accuracy: 34.599999999999994%
# epoch 6
# Best validation accuracy! iteration:1300 accuracy: 35.0%
# Best validation accuracy! iteration:1400 accuracy: 35.8%
# epoch 7
# Best validation accuracy! iteration:1500 accuracy: 36.2%
# Best validation accuracy! iteration:1600 accuracy: 37.6%
# epoch 8
# Best validation accuracy! iteration:1800 accuracy: 38.8%
# epoch 9
# Best validation accuracy! iteration:2000 accuracy: 39.3%
# Best validation accuracy! iteration:2100 accuracy: 39.9%
# Best validation accuracy! iteration:2200 accuracy: 40.4%
# epoch 10
# Best validation accuracy! iteration:2400 accuracy: 40.8%
# epoch 11
# Best validation accuracy! iteration:2500 accuracy: 41.8%
# epoch 12
# Best validation accuracy! iteration:2700 accuracy: 42.6%
# Best validation accuracy! iteration:2800 accuracy: 43.3%
# epoch 13
# Best validation accuracy! iteration:3000 accuracy: 43.6%
# Best validation accuracy! iteration:3100 accuracy: 43.9%
# epoch 14
# Best validation accuracy! iteration:3200 accuracy: 44.4%
# Best validation accuracy! iteration:3300 accuracy: 44.7%
# Best validation accuracy! iteration:3400 accuracy: 45.1%
# epoch 15
# Best validation accuracy! iteration:3500 accuracy: 45.2%
# Best validation accuracy! iteration:3600 accuracy: 45.9%
# epoch 16
# epoch 17
# Best validation accuracy! iteration:4000 accuracy: 46.3%
# Best validation accuracy! iteration:4100 accuracy: 46.6%
# epoch 18
# epoch 19
# Best validation accuracy! iteration:4500 accuracy: 47.2%
# epoch 20
# Traning ends. The best valid accuracy is 47.2. Model named lenet_1509723344.
# iteration 4:
#
# kernel size: 6
#
# penalty: 0.0001
#
# learning rate: 0.1
#
# batch size: 300
#
# Building my LeNet. Parameters:
# conv_featmap=[12]
# fc_units=[128, 84]
# conv_kernel_size=[6]
# pooling_size=[1]
# l2_norm=0.1
# seed=235
# learning_rate=0.0001
# number of batches for training: 163
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 37.7%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 39.5%
# Best validation accuracy! iteration:300 accuracy: 41.8%
# epoch 3
# Best validation accuracy! iteration:400 accuracy: 45.7%
# epoch 4
# epoch 5
# Best validation accuracy! iteration:700 accuracy: 46.9%
# epoch 6
# epoch 7
# epoch 8
# epoch 9
# epoch 10
# epoch 11
# epoch 12
# epoch 13
# epoch 14
# epoch 15
# epoch 16
# epoch 17
# epoch 18
# epoch 19
# epoch 20
# Traning ends. The best valid accuracy is 46.9. Model named lenet_1509723402.
# iteration 5:
#
# kernel size: 5
#
# penalty: 1e-05
#
# learning rate: 0.001
#
# batch size: 300
#
# Building my LeNet. Parameters:
# conv_featmap=[8]
# fc_units=[128, 84]
# conv_kernel_size=[5]
# pooling_size=[3]
# l2_norm=0.001
# seed=235
# learning_rate=1e-05
# number of batches for training: 163
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 12.0%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 17.700000000000003%
# Best validation accuracy! iteration:300 accuracy: 20.900000000000006%
# epoch 3
# Best validation accuracy! iteration:400 accuracy: 24.299999999999997%
# epoch 4
# Best validation accuracy! iteration:500 accuracy: 26.200000000000003%
# Best validation accuracy! iteration:600 accuracy: 27.599999999999994%
# epoch 5
# Best validation accuracy! iteration:700 accuracy: 28.0%
# Best validation accuracy! iteration:800 accuracy: 28.099999999999994%
# epoch 6
# Best validation accuracy! iteration:900 accuracy: 29.5%
# epoch 7
# Best validation accuracy! iteration:1000 accuracy: 30.299999999999997%
# Best validation accuracy! iteration:1100 accuracy: 30.5%
# epoch 8
# Best validation accuracy! iteration:1200 accuracy: 31.299999999999997%
# Best validation accuracy! iteration:1300 accuracy: 31.599999999999994%
# epoch 9
# Best validation accuracy! iteration:1400 accuracy: 32.8%
# epoch 10
# Best validation accuracy! iteration:1500 accuracy: 33.3%
# epoch 11
# Best validation accuracy! iteration:1700 accuracy: 33.8%
# epoch 12
# Best validation accuracy! iteration:1800 accuracy: 33.900000000000006%
# Best validation accuracy! iteration:1900 accuracy: 34.2%
# epoch 13
# Best validation accuracy! iteration:2000 accuracy: 35.400000000000006%
# epoch 14
# Best validation accuracy! iteration:2200 accuracy: 35.900000000000006%
# epoch 15
# Best validation accuracy! iteration:2400 accuracy: 36.2%
# epoch 16
# epoch 17
# Best validation accuracy! iteration:2700 accuracy: 36.8%
# epoch 18
# Best validation accuracy! iteration:2900 accuracy: 37.2%
# epoch 19
# epoch 20
# Best validation accuracy! iteration:3100 accuracy: 37.5%
# Best validation accuracy! iteration:3200 accuracy: 37.9%
# Traning ends. The best valid accuracy is 37.9. Model named lenet_1509723465.
# iteration 6:
#
# kernel size: 4
#
# penalty: 1e-05
#
# learning rate: 0.1
#
# batch size: 250
#
# Building my LeNet. Parameters:
# conv_featmap=[8]
# fc_units=[128, 84]
# conv_kernel_size=[4]
# pooling_size=[2]
# l2_norm=0.1
# seed=235
# learning_rate=1e-05
# number of batches for training: 196
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 17.5%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 20.299999999999997%
# Best validation accuracy! iteration:300 accuracy: 22.200000000000003%
# epoch 3
# Best validation accuracy! iteration:400 accuracy: 26.099999999999994%
# Best validation accuracy! iteration:500 accuracy: 27.599999999999994%
# epoch 4
# Best validation accuracy! iteration:600 accuracy: 29.099999999999994%
# Best validation accuracy! iteration:700 accuracy: 29.599999999999994%
# epoch 5
# Best validation accuracy! iteration:800 accuracy: 30.900000000000006%
# Best validation accuracy! iteration:900 accuracy: 31.099999999999994%
# epoch 6
# Best validation accuracy! iteration:1000 accuracy: 32.7%
# Best validation accuracy! iteration:1100 accuracy: 33.0%
# epoch 7
# Best validation accuracy! iteration:1200 accuracy: 33.8%
# Best validation accuracy! iteration:1300 accuracy: 34.599999999999994%
# epoch 8
# Best validation accuracy! iteration:1500 accuracy: 34.900000000000006%
# epoch 9
# epoch 10
# Best validation accuracy! iteration:1800 accuracy: 35.400000000000006%
# epoch 11
# Best validation accuracy! iteration:2000 accuracy: 36.2%
# Best validation accuracy! iteration:2100 accuracy: 36.3%
# epoch 12
# Best validation accuracy! iteration:2200 accuracy: 36.6%
# Best validation accuracy! iteration:2300 accuracy: 36.7%
# epoch 13
# Best validation accuracy! iteration:2500 accuracy: 36.8%
# epoch 14
# epoch 15
# Best validation accuracy! iteration:2800 accuracy: 37.4%
# epoch 16
# Best validation accuracy! iteration:3100 accuracy: 37.5%
# epoch 17
# Best validation accuracy! iteration:3200 accuracy: 37.7%
# Best validation accuracy! iteration:3300 accuracy: 38.1%
# epoch 18
# Best validation accuracy! iteration:3500 accuracy: 38.7%
# epoch 19
# epoch 20
# Best validation accuracy! iteration:3800 accuracy: 38.8%
# Traning ends. The best valid accuracy is 38.8. Model named lenet_1509723506.
# iteration 7:
#
# kernel size: 6
#
# penalty: 1e-05
#
# learning rate: 0.001
#
# batch size: 300
#
# Building my LeNet. Parameters:
# conv_featmap=[12]
# fc_units=[128, 84]
# conv_kernel_size=[6]
# pooling_size=[3]
# l2_norm=0.001
# seed=235
# learning_rate=1e-05
# number of batches for training: 163
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 16.5%
# epoch 2
# Best validation accuracy! iteration:200 accuracy: 23.900000000000006%
# Best validation accuracy! iteration:300 accuracy: 24.200000000000003%
# epoch 3
# Best validation accuracy! iteration:400 accuracy: 25.900000000000006%
# epoch 4
# Best validation accuracy! iteration:500 accuracy: 26.900000000000006%
# Best validation accuracy! iteration:600 accuracy: 27.5%
# epoch 5
# Best validation accuracy! iteration:700 accuracy: 29.0%
# epoch 6
# Best validation accuracy! iteration:900 accuracy: 29.299999999999997%
# epoch 7
# Best validation accuracy! iteration:1000 accuracy: 30.5%
# epoch 8
# Best validation accuracy! iteration:1200 accuracy: 31.200000000000003%
# Best validation accuracy! iteration:1300 accuracy: 32.7%
# epoch 9
# Best validation accuracy! iteration:1400 accuracy: 33.0%
# epoch 10
# Best validation accuracy! iteration:1500 accuracy: 33.599999999999994%
# Best validation accuracy! iteration:1600 accuracy: 34.599999999999994%
# epoch 11
# Best validation accuracy! iteration:1700 accuracy: 35.5%
# epoch 12
# Best validation accuracy! iteration:1800 accuracy: 36.0%
# Best validation accuracy! iteration:1900 accuracy: 36.6%
# epoch 13
# Best validation accuracy! iteration:2000 accuracy: 37.6%
# epoch 14
# Best validation accuracy! iteration:2200 accuracy: 38.2%
# epoch 15
# Best validation accuracy! iteration:2300 accuracy: 38.8%
# Best validation accuracy! iteration:2400 accuracy: 39.3%
# epoch 16
# epoch 17
# Best validation accuracy! iteration:2700 accuracy: 40.4%
# epoch 18
# Best validation accuracy! iteration:2900 accuracy: 40.8%
# epoch 19
# epoch 20
# Best validation accuracy! iteration:3100 accuracy: 40.9%
# Best validation accuracy! iteration:3200 accuracy: 41.1%
# Traning ends. The best valid accuracy is 41.1. Model named lenet_1509723546.
# iteration 8:
#
# kernel size: 5
#
# penalty: 1e-05
#
# learning rate: 0.001
#
# batch size: 200
#
# Building my LeNet. Parameters:
# conv_featmap=[8]
# fc_units=[128, 84]
# conv_kernel_size=[5]
# pooling_size=[3]
# l2_norm=0.001
# seed=235
# learning_rate=1e-05
# number of batches for training: 245
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 11.799999999999997%
# Best validation accuracy! iteration:200 accuracy: 17.5%
# epoch 2
# Best validation accuracy! iteration:300 accuracy: 21.099999999999994%
# Best validation accuracy! iteration:400 accuracy: 23.400000000000006%
# epoch 3
# Best validation accuracy! iteration:500 accuracy: 26.0%
# Best validation accuracy! iteration:600 accuracy: 27.200000000000003%
# epoch 4
# Best validation accuracy! iteration:800 accuracy: 28.200000000000003%
# Best validation accuracy! iteration:900 accuracy: 28.400000000000006%
# epoch 5
# Best validation accuracy! iteration:1000 accuracy: 29.400000000000006%
# Best validation accuracy! iteration:1100 accuracy: 30.400000000000006%
# Best validation accuracy! iteration:1200 accuracy: 30.599999999999994%
# epoch 6
# Best validation accuracy! iteration:1300 accuracy: 31.200000000000003%
# Best validation accuracy! iteration:1400 accuracy: 31.900000000000006%
# epoch 7
# Best validation accuracy! iteration:1600 accuracy: 33.0%
# epoch 8
# Best validation accuracy! iteration:1800 accuracy: 33.5%
# epoch 9
# Best validation accuracy! iteration:2000 accuracy: 34.400000000000006%
# Best validation accuracy! iteration:2200 accuracy: 34.5%
# epoch 10
# Best validation accuracy! iteration:2300 accuracy: 35.2%
# Best validation accuracy! iteration:2400 accuracy: 35.3%
# epoch 11
# Best validation accuracy! iteration:2500 accuracy: 36.0%
# epoch 12
# epoch 13
# Best validation accuracy! iteration:3100 accuracy: 36.7%
# epoch 14
# Best validation accuracy! iteration:3200 accuracy: 36.8%
# Best validation accuracy! iteration:3300 accuracy: 37.0%
# epoch 15
# Best validation accuracy! iteration:3600 accuracy: 38.0%
# epoch 16
# Best validation accuracy! iteration:3700 accuracy: 38.3%
# Best validation accuracy! iteration:3800 accuracy: 38.7%
# epoch 17
# Best validation accuracy! iteration:4100 accuracy: 38.9%
# epoch 18
# Best validation accuracy! iteration:4200 accuracy: 39.1%
# Best validation accuracy! iteration:4300 accuracy: 39.5%
# epoch 19
# Best validation accuracy! iteration:4600 accuracy: 39.7%
# epoch 20
# Best validation accuracy! iteration:4700 accuracy: 40.0%
# Best validation accuracy! iteration:4800 accuracy: 40.2%
# Traning ends. The best valid accuracy is 40.2. Model named lenet_1509723595.
# iteration 9:
#
# kernel size: 4
#
# penalty: 0.0001
#
# learning rate: 0.001
#
# batch size: 200
#
# Building my LeNet. Parameters:
# conv_featmap=[10]
# fc_units=[128, 84]
# conv_kernel_size=[4]
# pooling_size=[2]
# l2_norm=0.001
# seed=235
# learning_rate=0.0001
# number of batches for training: 245
# epoch 1
# Best validation accuracy! iteration:100 accuracy: 32.099999999999994%
# Best validation accuracy! iteration:200 accuracy: 35.900000000000006%
# epoch 2
# Best validation accuracy! iteration:300 accuracy: 42.4%
# Best validation accuracy! iteration:400 accuracy: 45.2%
# epoch 3
# Best validation accuracy! iteration:600 accuracy: 46.9%
# Best validation accuracy! iteration:700 accuracy: 47.8%
# epoch 4
# Best validation accuracy! iteration:800 accuracy: 48.2%
# epoch 5
# Best validation accuracy! iteration:1000 accuracy: 49.4%
# Best validation accuracy! iteration:1100 accuracy: 50.3%
# Best validation accuracy! iteration:1200 accuracy: 50.5%
# epoch 6
# Best validation accuracy! iteration:1300 accuracy: 51.6%
# Best validation accuracy! iteration:1400 accuracy: 52.3%
# epoch 7
# epoch 8
# Best validation accuracy! iteration:1800 accuracy: 52.7%
# epoch 9
# Best validation accuracy! iteration:2000 accuracy: 53.1%
# Best validation accuracy! iteration:2200 accuracy: 53.6%
# epoch 10
# Best validation accuracy! iteration:2300 accuracy: 53.8%
# Best validation accuracy! iteration:2400 accuracy: 54.1%
# epoch 11
# epoch 12
# Best validation accuracy! iteration:2800 accuracy: 55.1%
# Best validation accuracy! iteration:2900 accuracy: 55.2%
# epoch 13
# epoch 14
# Best validation accuracy! iteration:3300 accuracy: 55.6%
# epoch 15
# epoch 16
# Best validation accuracy! iteration:3800 accuracy: 56.5%
# epoch 17
# epoch 18
# epoch 19
# Best validation accuracy! iteration:4500 accuracy: 57.2%
# epoch 20
# Traning ends. The best valid accuracy is 57.2. Model named lenet_1509723640.

# %%
tune_results
# Out:
# [37.0,
#  43.100000000000001,
#  41.600000000000001,
#  47.200000000000003,
#  46.899999999999999,
#  37.899999999999999,
#  38.799999999999997,
#  41.100000000000001,
#  40.200000000000003,
#  57.200000000000003]

# %%
best = [i for i, r in enumerate(results) if r == max(results)]

parameters[best[0]]
# Out:
# ['lenet_1509670317',
#  [10],
#  [84, 84],
#  [5],
#  [2],
#  0.0001,
#  235,
#  0.001,
#  20,
#  245,
#  False,
#  None,
#  True]

# %% [markdown]
# <span style="color:red">__TODO:__</span> replace the example image with your own tensorboard graph screenshot.
# ![Tensorboard_2](./ecbm4040/notebook_images/task3_2_2.png)

# %%
# show the graph
from ecbm4040.neuralnets.cnn_jupyter_tensorboard import show_graph 
tf.reset_default_graph()
with tf.Session() as sess:
    saver = tf.train.import_meta_graph('model/[YOUR_MODEL_NAME].meta')
    graph = tf.get_default_graph()
    show_graph(graph)
